# %%
import pandas as pd
import numpy as np
from imblearn.under_sampling import TomekLinks, OneSidedSelection, RandomUnderSampler
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/home/estsoft/data/train.csv')
df_tst = pd.read_csv('/home/estsoft/data/test.csv')

# %%
label = LabelEncoder()
df.loc[:,:] = df.loc[:,:].apply(label.fit_transform)

# %%
sns.set(rc = {'font.family':'NanumGothic'})
fig, axes = plt.subplots(2, 2, figsize=(10, 8))
sns.countplot(data=df, x='ECLO', ax=axes[0, 0])
axes[0, 0].set_title('기상상태 분포')
plt.tight_layout()
plt.show()
# Out:
# /home/estsoft/miniconda3/envs/Popcorn/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/estsoft/miniconda3/envs/Popcorn/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/estsoft/miniconda3/envs/Popcorn/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
from imblearn.under_sampling import TomekLinks, OneSidedSelection, RandomUnderSampler, EditedNearestNeighbours

# y = df['ECLO']
# ada = OneSidedSelection(sampling_strategy='majority', random_state=2023)
# df_oneside, y_oneside = ada.fit_resample(df, y)

# %%
sns.set(rc = {'font.family':'NanumGothic'})
fig, axes = plt.subplots(2, 2, figsize=(10, 8))
sns.countplot(data=df_oneside, x='ECLO', ax=axes[0, 0])
axes[0, 0].set_title('기상상태 분포')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/leeus/work/est_wassup_01/test_.ipynb Cell 6 line 3
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22455354536f6674207b4131362d34307d227d/home/leeus/work/est_wassup_01/test_.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> sns.set(rc = {'font.family':'NanumGothic'})
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22455354536f6674207b4131362d34307d227d/home/leeus/work/est_wassup_01/test_.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> fig, axes = plt.subplots(2, 2, figsize=(10, 8))
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22455354536f6674207b4131362d34307d227d/home/leeus/work/est_wassup_01/test_.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> sns.countplot(data=df_oneside, x='ECLO', ax=axes[0, 0])
# ...

# %%
y = df['ECLO']

ada = OneSidedSelection(sampling_strategy='majority', random_state=2023)
df_rand, y_rand = ada.fit_resample(df, y)
ada = TomekLinks(sampling_strategy='majority')
df_resam, y_resam = ada.fit_resample(df_rand, y_rand)
df_resam, y_resam = ada.fit_resample(df_resam, y_resam)
df_resam, y_resam = ada.fit_resample(df_resam, y_resam)

# %%
sns.set(rc = {'font.family':'NanumGothic'})
fig, axes = plt.subplots(2, 2, figsize=(10, 8))
sns.countplot(data=df_resam, x='ECLO', ax=axes[0, 0])
axes[0, 0].set_title('기상상태 분포')
sns.countplot(data=df_oneside, x='ECLO', ax=axes[0, 1])
sns.countplot(data=df_rand, x='ECLO', ax=axes[1, 0])
plt.tight_layout()
plt.show()
# Out:
# /home/estsoft/miniconda3/envs/MathAI/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/estsoft/miniconda3/envs/MathAI/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/estsoft/miniconda3/envs/MathAI/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ---------------------------------------------------------------------------
# ...

# %%
y = df['ECLO']
ada = EditedNearestNeighbours(sampling_strategy='majority')
df_enn, y_enn = ada.fit_resample(df, y)
ada_one = OneSidedSelection(sampling_strategy='majority', random_state=2023)
df_rand, y_rand = ada_one.fit_resample(df, y)
df_rand, y_rand = ada_one.fit_resample(df_rand, y_rand)
df_rand, y_rand = ada_one.fit_resample(df_rand, y_rand)
df_rand, y_rand = ada_one.fit_resample(df_rand, y_rand)

ada = EditedNearestNeighbours(sampling_strategy='majority')
df_enn, y_enn = ada.fit_resample(df, y)
ada_one = OneSidedSelection(sampling_strategy='majority', random_state=2023)
df_rand2, y_rand2 = ada_one.fit_resample(df_enn, y_enn)
df_rand2, y_rand2 = ada_one.fit_resample(df_rand2, y_rand2)
df_rand2, y_rand2 = ada_one.fit_resample(df_rand2, y_rand2)


sns.set(rc = {'font.family':'NanumGothic'})
fig, axes = plt.subplots(3, 3, figsize=(10, 8))
sns.countplot(data=df_resam, x='ECLO', ax=axes[0, 0])
axes[0, 0].set_title('기상상태 분포')
sns.countplot(data=df_oneside, x='ECLO', ax=axes[0, 1])
sns.countplot(data=df_rand, x='ECLO', ax=axes[1, 0])
sns.countplot(data=df_enn, x='ECLO', ax=axes[1, 1])
sns.countplot(data=df_rand, x='ECLO', ax=axes[2, 0])
sns.countplot(data=df_rand2, x='ECLO', ax=axes[2, 1])
plt.tight_layout()
plt.show()
# Out:
# /home/estsoft/miniconda3/envs/MathAI/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/estsoft/miniconda3/envs/MathAI/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/estsoft/miniconda3/envs/MathAI/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ---------------------------------------------------------------------------
# ...

# %%
sns.set(rc={'font.family': 'NanumGothic'})
plt.figure(figsize=(10, 2)) 
sns.countplot(data=df_rand, x='ECLO')
plt.title('resampling 후 ECLO 분포')
plt.show()
# Out:
# /home/estsoft/miniconda3/envs/MathAI/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/estsoft/miniconda3/envs/MathAI/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/estsoft/miniconda3/envs/MathAI/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
ada = RandomUnderSampler(sampling_strategy='majority', random_state=2023)
df_rand, y_rand = ada.fit_resample(df, y)

# %%
sns.set(rc = {'font.family':'NanumGothic'})
fig, axes = plt.subplots(2, 2, figsize=(10, 8))
sns.countplot(data=df_resam, x='ECLO', ax=axes[0, 0])
axes[0, 0].set_title('기상상태 분포')
sns.countplot(data=df_oneside, x='ECLO', ax=axes[0, 1])
sns.countplot(data=df_rand, x='ECLO', ax=axes[1, 0])
plt.tight_layout()
plt.show()
# Out:
# /home/estsoft/miniconda3/envs/Popcorn/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/estsoft/miniconda3/envs/Popcorn/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/estsoft/miniconda3/envs/Popcorn/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
print(df.info())
print('-------------------')
print(df_tst.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39609 entries, 0 to 39608
# Data columns (total 23 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           39609 non-null  object
#  1   사고일시         39609 non-null  object
#  2   요일           39609 non-null  object
#  3   기상상태         39609 non-null  object
#  4   시군구          39609 non-null  object
#  5   도로형태         39609 non-null  object
#  6   노면상태         39609 non-null  object
#  7   사고유형         39609 non-null  object
#  8   사고유형 - 세부분류  39609 non-null  object
#  9   법규위반         39609 non-null  object
#  10  가해운전자 차종     39609 non-null  object
#  11  가해운전자 성별     39609 non-null  object
#  12  가해운전자 연령     39609 non-null  object
#  13  가해운전자 상해정도   39609 non-null  object
#  14  피해운전자 차종     38618 non-null  object
#  15  피해운전자 성별     38618 non-null  object
#  16  피해운전자 연령     38618 non-null  object
#  17  피해운전자 상해정도   38618 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# ID               0
# 사고일시             0
# 요일               0
# 기상상태             0
# 시군구              0
# 도로형태             0
# 노면상태             0
# 사고유형             0
# 사고유형 - 세부분류      0
# 법규위반             0
# 가해운전자 차종         0
# 가해운전자 성별         0
# 가해운전자 연령         0
# 가해운전자 상해정도       0
# 피해운전자 차종       991
# 피해운전자 성별       991
# 피해운전자 연령       991
# 피해운전자 상해정도     991
# 사망자수             0
# 중상자수             0
# 경상자수             0
# 부상자수             0
# ECLO             0
# dtype: int64

# %%
df[['피해운전자 상해정도','피해운전자 연령','피해운전자 성별','피해운전자 차종']]
# Out:
#       피해운전자 상해정도 피해운전자 연령 피해운전자 성별 피해운전자 차종
# 0             중상      70세        여      보행자
# 1             경상      61세        남      보행자
# 2             경상      38세        남      보행자
# 3             중상      36세        남       승용
# 4             경상      52세        남       승용
# ...          ...      ...      ...      ...
# 39604         경상      28세        남       이륜
# 39605         경상      52세        남       승용
# 39606         중상      73세        남       승용
# 39607         경상      57세        여       승용
# 39608         경상      33세        남       승용
#
# [39609 rows x 4 columns]

# %%
from imblearn.over_sampling import ADASYN, SMOTE

# %%
X_resampled, y_resampled = ADASYN(sampling_strategy=strategy).fit_resample(X, y)
count_and_plot(y_resampled)

# %%
print(df.columns)
y_train = df['ECLO']
x = df.drop(['ECLO','사망자수','중상자수','경상자수','부상자수'],axis=1)
#x = df['ECLO'].drop
# Out:
# Index(['ID', '사고일시', '요일', '기상상태', '시군구', '도로형태', '노면상태', '사고유형',
#        '사고유형 - 세부분류', '법규위반', '가해운전자 차종', '가해운전자 성별', '가해운전자 연령', '가해운전자 상해정도',
#        '피해운전자 차종', '피해운전자 성별', '피해운전자 연령', '피해운전자 상해정도', '사망자수', '중상자수',
#        '경상자수', '부상자수', 'ECLO'],
#       dtype='object')

# %%
X_resampled, y_resampled = SMOTE(random_state=0).fit_resample(x, y)
count_and_plot(y_resampled)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/leeus/work/est_wassup_01/test_.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22455354536f6674207b4131362d34307d227d/home/leeus/work/est_wassup_01/test_.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> X_resampled, y_resampled = SMOTE(random_state=0).fit_resample(x, y)
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22455354536f6674207b4131362d34307d227d/home/leeus/work/est_wassup_01/test_.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> count_and_plot(y_resampled)
#
# File /home/estsoft/miniconda3/envs/Popcorn/lib/python3.10/site-packages/imblearn/base.py:208, in BaseSampler.fit_resample(self, X, y)
#     187 """Resample the dataset.
#     188
#     189 Parameters
#    (...)
#     205     The corresponding label of `X_resampled`.
#     206 """
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df.loc[:,:]
# Out:
#                    ID           사고일시   요일 기상상태              시군구  \
# 0      ACCIDENT_00000  2019-01-01 00  화요일   맑음     대구광역시 중구 대신동
# 1      ACCIDENT_00001  2019-01-01 00  화요일   흐림    대구광역시 달서구 감삼동
# 2      ACCIDENT_00002  2019-01-01 01  화요일   맑음    대구광역시 수성구 두산동
# 3      ACCIDENT_00003  2019-01-01 02  화요일   맑음     대구광역시 북구 복현동
# 4      ACCIDENT_00004  2019-01-01 04  화요일   맑음     대구광역시 동구 신암동
# ...               ...            ...  ...  ...              ...
# 39604  ACCIDENT_39604  2021-12-31 19  금요일   맑음  대구광역시 수성구 수성동3가
# 39605  ACCIDENT_39605  2021-12-31 19  금요일   맑음    대구광역시 달서구 상인동
# 39606  ACCIDENT_39606  2021-12-31 21  금요일   맑음    대구광역시 달서구 월성동
# 39607  ACCIDENT_39607  2021-12-31 22  금요일   맑음     대구광역시 달서구 장동
# 39608  ACCIDENT_39608  2021-12-31 23  금요일   맑음     대구광역시 서구 비산동
#
#                   도로형태 노면상태  사고유형 사고유형 - 세부분류       법규위반  ... 가해운전자 상해정도  \
# 0             단일로 - 기타   건조  차대사람  길가장자리구역통행중    안전운전불이행  ...       상해없음
# ...

# %%
le = LabelEncoder()

# %%
y = le.fit_transform(y)
x = le.fit_transform(x)

# %%
list1 = [1]
list2 = [3]

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_squared_log_error
mean_squared_log_error(list1,list2,squared=True)
# Out:
# 0.4804530139182014

# %%
import pandas as pd
df_tst = pd.DataFrame()

# %%
df_tst.loc[:,:] = df_tst.loc[:,:].apply(label.fit_transform)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/leeus/work/est_wassup_01/test_.ipynb Cell 19 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22455354536f6674207b4131362d34307d227d/home/leeus/work/est_wassup_01/test_.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> df_tst.loc[:,:] = df_tst.loc[:,:].apply(label.fit_transform)
#
# NameError: name 'label' is not defined
